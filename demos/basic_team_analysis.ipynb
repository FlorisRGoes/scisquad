# %% [markdown]
# # Analyze a team - benchmarked to a given league

# %%
import os

from dotenv import load_dotenv

from scisquad.api.domain import ApiCredentials
from scisquad.api.entities import LeaguesAPI
from scisquad.api.entities import TeamsAPI
from scisquad.model.entities import LeagueType
from scisquad.model.entities import Gender
from scisquad.model.entities import Nations
from scisquad.insights.league import SeasonTeamInsights

# %% [markdown]
# ## Set Parameters

# %%
load_dotenv()
# Out:
# True

# %%
credentials = ApiCredentials(
    username=os.getenv("API_USER"),
    password=os.getenv("API_PW"),
    client_id=os.getenv("API_CLIENT_ID"),
    client_secret=os.getenv("API_CLIENT_SECRET"),
)

# %% [markdown]
# ## Connect with API

# %%
API = LeaguesAPI(credentials)

# %% [markdown]
# ## Get League, Teams & Seasons

# %%
leagues = API.get_leagues(
    league_types=[LeagueType.DOMESTIC_LEAGUE],
    gender=[Gender.MALE],
    nations=[Nations.NLD]
)
seasons = API.get_league_seasons(leagues[0])
# Out:
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200

# %% [markdown]
# ## Aggregate Team Insights

# %%
LA = SeasonTeamInsights(seasons[0], TeamsAPI(credentials))
df_performance_insights, df_inbound_transfer_insights, df_outbound_transfer_insights, df_revenue_insights = LA.analyze_teams()
# Out:
# Processing all teams in Eredivisie (2025/2026):   0%|          | 0/18 [00:00<?, ?it/s]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):   6%|▌         | 1/18 [00:19<05:34, 19.67s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  11%|█         | 2/18 [00:29<03:45, 14.07s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  17%|█▋        | 3/18 [00:40<03:05, 12.35s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  22%|██▏       | 4/18 [00:49<02:38, 11.35s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  28%|██▊       | 5/18 [00:59<02:18, 10.63s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  33%|███▎      | 6/18 [01:09<02:03, 10.32s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  39%|███▉      | 7/18 [01:18<01:51, 10.18s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  44%|████▍     | 8/18 [01:28<01:39,  9.94s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  50%|█████     | 9/18 [01:38<01:29,  9.91s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  56%|█████▌    | 10/18 [01:47<01:18,  9.78s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  61%|██████    | 11/18 [01:56<01:05,  9.40s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  67%|██████▋   | 12/18 [02:06<00:57,  9.56s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  72%|███████▏  | 13/18 [02:14<00:46,  9.29s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  78%|███████▊  | 14/18 [02:23<00:36,  9.03s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  83%|████████▎ | 15/18 [02:32<00:26,  8.99s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  89%|████████▉ | 16/18 [02:41<00:18,  9.16s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026):  94%|█████████▍| 17/18 [02:51<00:09,  9.49s/it]
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Request completed: 200
# Processing all teams in Eredivisie (2025/2026): 100%|██████████| 18/18 [03:00<00:00, 10.04s/it]
# Request completed: 200
# Request completed: 200
# Analyzing all teams in Eredivisie (2025/2026):   0%|          | 0/18 [00:00<?, ?it/s]/Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# Analyzing all teams in Eredivisie (2025/2026):  17%|█▋        | 3/18 [00:00<00:00, 27.56it/s]/Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# ...
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# Analyzing all teams in Eredivisie (2025/2026):  72%|███████▏  | 13/18 [00:00<00:00, 37.77it/s]/Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# Analyzing all teams in Eredivisie (2025/2026):  94%|█████████▍| 17/18 [00:00<00:00, 38.16it/s]/Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:41: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_end_loan'] = self._data['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:42: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._data['is_loan'] = self._data['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:275: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_end_loan'] = self._transfers['is_end_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:276: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._transfers['is_loan'] = self._transfers['is_loan'].fillna(False).astype(bool)
# /Users/florisgoes/scisquad/scisquad/insights/squad.py:255: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self._squad['academy_player'] = self._squad['academy_player'].fillna(False).astype(bool)
# Analyzing all teams in Eredivisie (2025/2026): 100%|██████████| 18/18 [00:00<00:00, 37.16it/s]

# %% [markdown]
# ## Inspect Results

# %%
df_performance_insights
# Out:
#     team_id            team_name primary_formation secondary_formation  \
# 0      1116         NEC Nijmegen           5-2-2-1             5-2-2-1
# 1      1115            NAC Breda           4-2-1-3             4-1-2-3
# 2      1131           SC Telstar           5-2-2-1             5-2-2-1
# 3      1121          FC Volendam           4-2-1-3             4-2-1-3
# 4      1100        PSV Eindhoven           4-1-2-3             4-1-2-3
# 5      1105         FC Groningen           4-2-1-3             4-2-1-3
# 6      1117      Go Ahead Eagles           4-2-1-3             4-2-1-3
# 7      1112     Sparta Rotterdam           4-2-1-3             4-1-2-3
# 8      1132      Fortuna Sittard             5-2-3             4-2-1-3
# 9      1103           AZ Alkmaar           4-2-1-3             4-1-2-3
# 10     1104            FC Twente           4-2-1-3             4-2-1-3
# 11     1101           FC Utrecht           4-2-1-3             4-2-1-3
# 12     1099       Ajax Amsterdam           4-2-1-3             4-1-2-3
# 13     1106        SC Heerenveen           4-2-1-3             4-2-1-3
# 14     1107      Heracles Almelo           4-2-1-3             4-2-1-3
# 15     1109  Excelsior Rotterdam           4-2-1-3             4-2-1-3
# 16     1098  Feyenoord Rotterdam           4-2-1-3             4-2-1-3
# 17     1111           PEC Zwolle           4-2-1-3             4-2-1-3
#
#     goals_scored  goals_conceded  matches_won  matches_drawn  matches_lost  \
# 0             12              12            0              3             0
# 1              2               2            0              3             0
# 2              2               2            0              3             0
# 3              5               5            0              3             0
# 4             11              11            0              3             0
# 5              6               6            0              3             0
# 6              3               3            0              3             0
# 7              6               6            0              3             0
# 8              4               4            0              2             0
# 9              5               5            0              2             0
# 10             1               1            0              2             0
# 11             5               5            0              2             0
# 12             4               4            0              2             0
# 13             2               2            0              2             0
# 14             1               1            0              2             0
# 15             1               1            0              2             0
# 16             4               4            0              2             0
# 17             3               3            0              2             0
#
#     goals_scored_per_game  goals_conceded_per_game  total_points  \
# 0                     4.0                      4.0           3.0
# 1                     0.7                      0.7           3.0
# 2                     0.7                      0.7           3.0
# 3                     1.7                      1.7           3.0
# 4                     3.7                      3.7           3.0
# 5                     2.0                      2.0           3.0
# 6                     1.0                      1.0           3.0
# 7                     2.0                      2.0           3.0
# 8                     2.0                      2.0           2.0
# 9                     2.5                      2.5           2.0
# 10                    0.5                      0.5           2.0
# 11                    2.5                      2.5           2.0
# 12                    2.0                      2.0           2.0
# 13                    1.0                      1.0           2.0
# 14                    0.5                      0.5           2.0
# 15                    0.5                      0.5           2.0
# 16                    2.0                      2.0           2.0
# 17                    1.5                      1.5           2.0
#
#     points_per_game  mean_sciskill  mean_potential  mean_sciskill_top_15  \
# 0               1.0           53.0            60.8                  62.1
# 1               1.0           39.9            48.9                  55.2
# 2               1.0           31.2            39.4                  43.0
# 3               1.0           39.7            54.6                  45.7
# 4               1.0           67.0            81.7                  77.7
# 5               1.0           40.7            52.2                  53.6
# 6               1.0           46.1            55.4                  57.3
# 7               1.0           47.0            58.0                  58.5
# 8               1.0           45.4            51.9                  53.2
# 9               1.0           58.4            77.1                  63.7
# 10              1.0           56.1            66.6                  64.4
# 11              1.0           55.0            66.3                  63.5
# 12              1.0           67.0            81.2                  70.6
# 13              1.0           49.9            63.9                  57.6
# 14              1.0           44.5            54.5                  53.6
# 15              1.0           45.1            60.9                  46.8
# 16              1.0           63.3            75.6                  67.9
# 17              1.0           47.2            56.7                  54.8
#
#     mean_potential_top_15  mean_sciskill_dev
# 0                    71.4                2.2
# 1                    68.8                0.3
# 2                    56.2                2.5
# 3                    58.9                1.8
# 4                    88.9                1.7
# 5                    70.2                1.0
# 6                    67.0                1.0
# 7                    70.3                0.3
# 8                    64.0                0.8
# 9                    79.4                0.8
# 10                   78.3                0.4
# 11                   73.1                1.9
# 12                   86.0                0.7
# 13                   71.2                2.4
# 14                   65.9               -0.2
# 15                   62.0                1.8
# 16                   79.5                1.5
# 17                   65.7                1.9

# %%
df_inbound_transfer_insights
# Out:
#     team_id            team_name  total_transfers  total_spend  \
# 0      1116         NEC Nijmegen               90      3550000
# 1      1115            NAC Breda               95      1635000
# 2      1131           SC Telstar              100            0
# 3      1121          FC Volendam               99            0
# 4      1100        PSV Eindhoven               74    169050000
# 5      1105         FC Groningen               85     14691000
# 6      1117      Go Ahead Eagles               98      8040000
# 7      1112     Sparta Rotterdam               95      2510000
# 8      1132      Fortuna Sittard               81      3870000
# 9      1103           AZ Alkmaar               75     62550000
# 10     1104            FC Twente               95     19550000
# 11     1101           FC Utrecht               80     10200000
# 12     1099       Ajax Amsterdam               83    447500000
# 13     1106        SC Heerenveen               93     27096000
# 14     1107      Heracles Almelo               89      4210000
# 15     1109  Excelsior Rotterdam              100      1625000
# 16     1098  Feyenoord Rotterdam               81    134115000
# 17     1111           PEC Zwolle               92      2025000
#
#     percentage_loans  percentage_free  \
# 0           0.277778         0.907692
# 1           0.168421         0.924051
# 2           0.190000         1.000000
# 3           0.171717         1.000000
# 4           0.202703         0.525424
# 5           0.223529         0.666667
# 6           0.112245         0.862069
# 7           0.263158         0.914286
# 8           0.296296         0.877193
# 9           0.106667         0.567164
# 10          0.368421         0.783333
# 11          0.225000         0.774194
# 12          0.096386         0.426667
# 13          0.258065         0.594203
# 14          0.101124         0.837500
# 15          0.240000         0.934211
# 16          0.185185         0.424242
# 17          0.271739         0.910448
#
#                                             fee_range  \
# 0   {'min': 0, 'mean': 54615.38461538462, 'max': 1...
# 1   {'min': 0, 'mean': 20696.20253164557, 'max': 4...
# 2                   {'min': 0, 'mean': 0.0, 'max': 0}
# 3                   {'min': 0, 'mean': 0.0, 'max': 0}
# 4   {'min': 0, 'mean': 2865254.2372881356, 'max': ...
# 5   {'min': 0, 'mean': 222590.9090909091, 'max': 2...
# 6   {'min': 0, 'mean': 92413.79310344828, 'max': 1...
# 7   {'min': 0, 'mean': 35857.142857142855, 'max': ...
# 8   {'min': 0, 'mean': 67894.73684210527, 'max': 1...
# 9   {'min': 0, 'mean': 933582.0895522388, 'max': 6...
# 10  {'min': 0, 'mean': 325833.3333333333, 'max': 5...
# 11  {'min': 0, 'mean': 164516.12903225806, 'max': ...
# 12  {'min': 0, 'mean': 5966666.666666667, 'max': 3...
# 13  {'min': 0, 'mean': 392695.652173913, 'max': 25...
# 14         {'min': 0, 'mean': 52625.0, 'max': 900000}
# 15  {'min': 0, 'mean': 21381.57894736842, 'max': 5...
# 16  {'min': 0, 'mean': 2032045.4545454546, 'max': ...
# 17  {'min': 0, 'mean': 30223.880597014926, 'max': ...
#
#                                    market_value_range  \
# 0   {'min': 0, 'mean': 460769.23076923075, 'max': ...
# 1   {'min': 0, 'mean': 290189.87341772154, 'max': ...
# 2   {'min': 0, 'mean': 128703.70370370371, 'max': ...
# 3   {'min': 0, 'mean': 182317.07317073172, 'max': ...
# 4   {'min': 0, 'mean': 4912288.135593221, 'max': 2...
# 5   {'min': 0, 'mean': 720075.7575757576, 'max': 9...
# 6   {'min': 0, 'mean': 339655.1724137931, 'max': 1...
# 7   {'min': 0, 'mean': 436428.5714285714, 'max': 1...
# 8   {'min': 0, 'mean': 538596.4912280702, 'max': 2...
# 9   {'min': 0, 'mean': 1278731.343283582, 'max': 6...
# 10  {'min': 0, 'mean': 816666.6666666666, 'max': 7...
# 11  {'min': 100000, 'mean': 1157661.2903225806, 'm...
# 12  {'min': 100000, 'mean': 6773333.333333333, 'ma...
# 13  {'min': 0, 'mean': 650724.6376811594, 'max': 3...
# 14       {'min': 0, 'mean': 342187.5, 'max': 1500000}
# 15  {'min': 0, 'mean': 301973.6842105263, 'max': 1...
# 16  {'min': 0, 'mean': 3095075.757575758, 'max': 1...
# 17  {'min': 0, 'mean': 391417.9104477612, 'max': 2...
#
#                             contract_years_left_range  \
# 0   {'min': 0.0, 'mean': 0.7510221285563752, 'max'...
# 1   {'min': 0.0, 'mean': 0.5960811513785331, 'max'...
# 2   {'min': 0.0, 'mean': 0.18461018095721293, 'max...
# 3   {'min': 0.0, 'mean': 0.9723020380888739, 'max'...
# 4   {'min': 0.0, 'mean': 1.1826793591827258, 'max'...
# 5   {'min': 0.0, 'mean': 0.9201743462017434, 'max'...
# 6   {'min': 0.0, 'mean': 0.47044559911824907, 'max...
# 7   {'min': 0.0, 'mean': 0.6032485322896282, 'max'...
# 8   {'min': 0.0, 'mean': 0.46882960826724346, 'max...
# 9   {'min': 0.0, 'mean': 1.5276630545900634, 'max'...
# 10  {'min': 0.0, 'mean': 0.7240182648401825, 'max'...
# 11  {'min': 0.0, 'mean': 0.946442775077331, 'max':...
# 12  {'min': 0.0, 'mean': 1.7564200913242007, 'max'...
# 13  {'min': -0.0027397260273972603, 'mean': 0.8658...
# 14  {'min': 0.0, 'mean': 0.7071575342465753, 'max'...
# 15  {'min': 0.0, 'mean': 0.660310021629416, 'max':...
# 16  {'min': 0.0, 'mean': 1.3034454130344542, 'max'...
# 17  {'min': 0.0, 'mean': 0.7361684727049683, 'max'...
#
#                                 inbound_market_shares
# 0   {'NLD': 0.5063291139240507, 'BEL': 0.063291139...
# 1   {'NLD': 0.5897435897435898, 'DEU': 0.064102564...
# 2   {'NLD': 0.676056338028169, 'ENG': 0.0845070422...
# 3   {'NLD': 0.8157894736842105, 'ITA': 0.052631578...
# 4   {'NLD': 0.34328358208955223, 'DEU': 0.16417910...
# 5   {'NLD': 0.4507042253521127, 'SWE': 0.098591549...
# 6   {'NLD': 0.5070422535211268, 'SWE': 0.056338028...
# 7   {'NLD': 0.6785714285714286, 'BEL': 0.059523809...
# 8   {'NLD': 0.234375, 'ENG': 0.140625, 'ITA': 0.09...
# 9   {'NLD': 0.5441176470588235, 'DNK': 0.058823529...
# 10  {'NLD': 0.46153846153846156, 'ENG': 0.10256410...
# 11  {'NLD': 0.5797101449275363, 'DEU': 0.159420289...
# 12  {'NLD': 0.3698630136986301, 'DEU': 0.095890410...
# 13  {'NLD': 0.43209876543209874, 'DEU': 0.08641975...
# 14  {'NLD': 0.49333333333333335, 'DEU': 0.2, 'ITA'...
# 15  {'NLD': 0.6235294117647059, 'BEL': 0.094117647...
# 16  {'NLD': 0.34328358208955223, 'BEL': 0.10447761...
# 17  {'NLD': 0.6103896103896104, 'DEU': 0.103896103...

# %%
df_outbound_transfer_insights
# Out:
#     team_id            team_name  total_transfers  total_earned  \
# 0      1116         NEC Nijmegen               84      27800000
# 1      1115            NAC Breda               91       6860000
# 2      1131           SC Telstar               86        300000
# 3      1121          FC Volendam               89       6925000
# 4      1100        PSV Eindhoven               90     385320000
# 5      1105         FC Groningen               85      62415000
# 6      1117      Go Ahead Eagles               90      20225000
# 7      1112     Sparta Rotterdam               82      27700000
# 8      1132      Fortuna Sittard               88       9250000
# 9      1103           AZ Alkmaar               95     241360000
# 10     1104            FC Twente               70      68150000
# 11     1101           FC Utrecht               88      52650000
# 12     1099       Ajax Amsterdam               94     780920000
# 13     1106        SC Heerenveen               85      64520000
# 14     1107      Heracles Almelo               96      24450000
# 15     1109  Excelsior Rotterdam               87      10773000
# 16     1098  Feyenoord Rotterdam               88     290600000
# 17     1111           PEC Zwolle               86      16125000
#
#     percentage_loans  percentage_free  \
# 0           0.154762         0.845070
# 1           0.043956         0.908046
# 2           0.011628         0.976471
# 3           0.044944         0.917647
# 4           0.266667         0.484848
# 5           0.270588         0.661290
# 6           0.088889         0.841463
# 7           0.146341         0.785714
# 8           0.250000         0.924242
# 9           0.336842         0.507937
# 10          0.142857         0.783333
# 11          0.284091         0.682540
# 12          0.308511         0.384615
# 13          0.082353         0.743590
# 14          0.104167         0.848837
# 15          0.057471         0.890244
# 16          0.409091         0.596154
# 17          0.093023         0.833333
#
#                                             fee_range  \
# 0   {'min': 0, 'mean': 391549.2957746479, 'max': 1...
# 1   {'min': 0, 'mean': 78850.57471264368, 'max': 2...
# 2   {'min': 0, 'mean': 3529.4117647058824, 'max': ...
# 3   {'min': 0, 'mean': 81470.58823529411, 'max': 3...
# 4   {'min': 0, 'mean': 5838181.818181818, 'max': 4...
# 5   {'min': 0, 'mean': 1006693.5483870967, 'max': ...
# 6   {'min': 0, 'mean': 246646.34146341463, 'max': ...
# 7   {'min': 0, 'mean': 395714.28571428574, 'max': ...
# 8   {'min': 0, 'mean': 140151.51515151514, 'max': ...
# 9   {'min': 0, 'mean': 3831111.111111111, 'max': 1...
# 10  {'min': 0, 'mean': 1135833.3333333333, 'max': ...
# 11  {'min': 0, 'mean': 835714.2857142857, 'max': 1...
# 12  {'min': 0, 'mean': 12014153.846153846, 'max': ...
# 13  {'min': 0, 'mean': 827179.4871794871, 'max': 1...
# 14  {'min': 0, 'mean': 284302.32558139536, 'max': ...
# 15  {'min': 0, 'mean': 131378.0487804878, 'max': 3...
# 16  {'min': 0, 'mean': 5588461.538461538, 'max': 3...
# 17  {'min': 0, 'mean': 206730.76923076922, 'max': ...
#
#                                    market_value_range  \
# 0   {'min': 0, 'mean': 651408.4507042253, 'max': 4...
# 1   {'min': 25000, 'mean': 348563.2183908046, 'max...
# 2   {'min': 25000, 'mean': 181764.70588235295, 'ma...
# 3   {'min': 0, 'mean': 269117.64705882355, 'max': ...
# 4   {'min': 50000, 'mean': 9154924.242424242, 'max...
# 5   {'min': 0, 'mean': 1144758.064516129, 'max': 1...
# 6   {'min': 25000, 'mean': 541158.5365853659, 'max...
# 7   {'min': 0, 'mean': 593214.2857142857, 'max': 3...
# 8   {'min': 0, 'mean': 531818.1818181818, 'max': 2...
# 9   {'min': 150000, 'mean': 4418650.793650794, 'ma...
# 10     {'min': 0, 'mean': 1830000.0, 'max': 16000000}
# 11  {'min': 100000, 'mean': 1270634.9206349207, 'm...
# 12  {'min': 0, 'mean': 12841923.076923076, 'max': ...
# 13  {'min': 0, 'mean': 1331410.2564102565, 'max': ...
# 14  {'min': 0, 'mean': 686337.2093023256, 'max': 4...
# 15  {'min': 25000, 'mean': 460365.85365853657, 'ma...
# 16  {'min': 100000, 'mean': 7178365.384615385, 'ma...
# 17  {'min': 0, 'mean': 606089.7435897436, 'max': 3...
#
#                             contract_years_left_range  \
# 0   {'min': 0.0, 'mean': 0.5166120007717537, 'max'...
# 1   {'min': 0.0, 'mean': 0.4741615493623052, 'max'...
# 2   {'min': 0.0, 'mean': 0.1895890410958904, 'max'...
# 3   {'min': 0.0, 'mean': 0.26697824335213544, 'max...
# 4   {'min': 0.0, 'mean': 1.0795765877957662, 'max'...
# 5   {'min': 0.0, 'mean': 0.8406098099867433, 'max'...
# 6   {'min': 0.0, 'mean': 0.3818576678917474, 'max'...
# 7   {'min': 0.0, 'mean': 0.583091976516634, 'max':...
# 8   {'min': 0.0, 'mean': 0.7687007056870071, 'max'...
# 9   {'min': 0.0, 'mean': 1.1145901282887583, 'max'...
# 10  {'min': 0.0, 'mean': 0.5665296803652969, 'max'...
# 11  {'min': 0.0, 'mean': 0.89706457925636, 'max': ...
# 12  {'min': 0.0, 'mean': 1.3608429926238144, 'max'...
# 13  {'min': 0.0, 'mean': 0.632384966631542, 'max':...
# 14  {'min': -0.0027397260273972603, 'mean': 0.4351...
# 15  {'min': 0.0, 'mean': 0.3761777480788506, 'max'...
# 16  {'min': 0.0, 'mean': 1.0697576396206534, 'max'...
# 17  {'min': 0.0, 'mean': 0.4468563400070249, 'max'...
#
#                                outbound_market_shares
# 0   {'NLD': 0.576271186440678, 'ITA': 0.0508474576...
# 1   {'NLD': 0.4642857142857143, 'BEL': 0.125, 'ESP...
# 2   {'NLD': 0.5909090909090909, 'ESP': 0.068181818...
# 3   {'NLD': 0.75, 'ENG': 0.057692307692307696, 'MA...
# 4   {'NLD': 0.23684210526315788, 'DEU': 0.17105263...
# 5   {'NLD': 0.463768115942029, 'ITA': 0.0869565217...
# 6   {'NLD': 0.6170212765957447, 'SWE': 0.063829787...
# 7   {'NLD': 0.603448275862069, 'ENG': 0.0862068965...
# 8   {'NLD': 0.4, 'PRT': 0.07692307692307693, 'TUR'...
# 9   {'NLD': 0.44871794871794873, 'ITA': 0.10256410...
# 10  {'NLD': 0.5, 'DEU': 0.10869565217391304, 'ITA'...
# 11  {'NLD': 0.6538461538461539, 'DEU': 0.051282051...
# 12  {'NLD': 0.18072289156626506, 'ENG': 0.14457831...
# 13  {'NLD': 0.288135593220339, 'SWE': 0.1016949152...
# 14  {'NLD': 0.4126984126984127, 'ENG': 0.079365079...
# 15  {'NLD': 0.49056603773584906, 'ITA': 0.05660377...
# 16  {'NLD': 0.44, 'ENG': 0.10666666666666667, 'DEU...
# 17  {'NLD': 0.41818181818181815, 'ENG': 0.09090909...

# %%
df_revenue_insights
# Out:
#     team_id            team_name  mean_age  mean_etv  total_etv  \
# 0      1116         NEC Nijmegen      25.9   1140000   29652000
# 1      1115            NAC Breda      23.5    623000   19335000
# 2      1131           SC Telstar      24.4    309000    9589000
# 3      1121          FC Volendam      24.0    597000   16129000
# 4      1100        PSV Eindhoven      24.6  10177000  264611000
# 5      1105         FC Groningen      22.7    894000   25934000
# 6      1117      Go Ahead Eagles      23.6    979000   30355000
# 7      1112     Sparta Rotterdam      26.5    916000   25671000
# 8      1132      Fortuna Sittard      23.5    552000   17665000
# 9      1103           AZ Alkmaar      23.5   4708000  127135000
# 10     1104            FC Twente      25.7   2592000   62216000
# 11     1101           FC Utrecht      24.8   1837000   58785000
# 12     1099       Ajax Amsterdam      25.6   8731000  200815000
# 13     1106        SC Heerenveen      23.3   1639000   40977000
# 14     1107      Heracles Almelo      24.4    713000   19987000
# 15     1109  Excelsior Rotterdam      23.0    687000   19259000
# 16     1098  Feyenoord Rotterdam      24.7   7263000  232421000
# 17     1111           PEC Zwolle      23.8    736000   18414000
#
#     mean_market_value  total_market_value  mean_etv_dev  total_etv_dev  \
# 0             1203000            27675000       -116000       -3003000
# 1              625000            15625000        -12000        -342000
# 2              296000             6225000        115000        3573000
# 3              360000             9000000        185000        5013000
# 4            10072000           241750000      -1462000      -37992000
# 5              831000            19125000        112000        3266000
# 6             1046000            28250000        231000        7162000
# 7              981000            23550000         55000        1566000
# 8              690000            19325000        -68000       -2165000
# 9             3931000           102225000       1709000       46152000
# 10            2467000            56750000       -330000       -7917000
# 11            2098000            62950000       -264000       -8438000
# 12            8717000           200500000        -89000       -2035000
# 13            1533000            36800000        361000        9037000
# 14             554000            14975000         27000         776000
# 15             515000            13925000        127000        3570000
# 16            6987000           223600000         30000         976000
# 17             813000            16275000        -19000        -469000
#
#     mean_etv_revenue  total_etv_revenue  mean_value_added  total_value_added  \
# 0            1026000           26694000            363000            9450000
# 1             545000           16902000            118000            3675000
# 2             275000            8543000             29000             925000
# 3             503000           13600000             41000            1125000
# 4            6841000          177880000           2194000           57050000
# 5             753000           21843000            178000            5175000
# 6             719000           22312000            457000           14175000
# 7             552000           15482000            207000            5800000
# 8             472000           15106000             89000            2875000
# 9            3714000          100302000           1442000           38950000
# 10           1828000           43888000            709000           17025000
# 11           1083000           34660000            435000           13950000
# 12           4291000           98715000           2004000           46100000
# 13           1069000           26735000            282000            7050000
# 14            559000           15678000            125000            3500000
# 15            485000           13603000            -42000           -1150000
# 16           4125000          132003000           1313000           42025000
# 17            524000           13101000             15000             375000
#
#     total_academy_etv  total_academy_etv_dev
# 0             3514000               -2468000
# 1              225000                 -20000
# 2                   0                      0
# 3             2435000                 894000
# 4            26212000                 940000
# 5             3478000                1861000
# 6              461000                -500000
# 7                   0                      0
# 8              901000                -423000
# 9            40810000               19326000
# 10           13133000               -8835000
# 11                  0                      0
# 12           57309000               19781000
# 13                  0                      0
# 14            1716000                 210000
# 15                  0                      0
# 16            1244000                -189000
# 17            1763000                  17000
